# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/DELL/Desktop/eda/train_energy_data.csv")

# %%
df.head(5)
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
df.head(5)
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
df.isna().sum()
# Out:
# Building Type          0
# Square Footage         0
# Number of Occupants    0
# Appliances Used        0
# Average Temperature    0
# Day of Week            0
# Energy Consumption     0
# dtype: int64

# %%
df.describe()
# Out:
#        Square Footage  Number of Occupants  Appliances Used  \
# count        1000.000          1000.000000      1000.000000
# mean        25462.388            48.372000        25.606000
# std         14294.554            29.061972        14.105166
# min           560.000             1.000000         1.000000
# 25%         13169.750            22.000000        13.000000
# 50%         25477.000            47.000000        26.000000
# 75%         37446.250            73.250000        38.000000
# max         49997.000            99.000000        49.000000
#
#        Average Temperature  Energy Consumption
# count          1000.000000         1000.000000
# mean             22.611390         4166.252570
# std               7.139943          933.313064
# min              10.050000         1683.950000
# 25%              16.475000         3509.482500
# 50%              22.815000         4175.730000
# 75%              28.850000         4863.850000
# ...

# %%
sns.relplot(x = "Appliances Used", y = "Energy Consumption", hue = "Building Type", data= df)

# %%
sns.displot(df["Energy Consumption"])

# %%
new_df = df.drop(["Building Type", "Day of Week"],axis = 1)

# %%
new_df.head(5)
# Out:
#    Square Footage  Number of Occupants  Appliances Used  Average Temperature  \
# 0            7063                   76               10                29.84
# 1           44372                   66               45                16.72
# 2           19255                   37               17                14.30
# 3           13265                   14               41                32.82
# 4           13375                   26               18                11.92
#
#    Energy Consumption
# 0             2713.95
# 1             5744.99
# 2             4101.24
# 3             3009.14
# 4             3279.17

# %%
sns.heatmap(new_df.corr(), xticklabels= new_df.corr().columns, annot = True)
# Out:
# <Axes: >

# %%
sns.relplot(x = "Number of Occupants" , y = "Energy Consumption", hue = "Day of Week" , data = df)

# %%
sns.relplot(x = "Average Temperature" , y = "Energy Consumption", hue = "Day of Week" , data = df)

# %% [markdown]
# CONCLUSIONS
#
# 1) There are no null values in given dataset
#
# 2) mean	square footage = 25462.388
#    mean no. of occupants = 48.372000
#    mean no. of appliances used = 25.606000
#    mean temperature = 22.611390
#    mean energy consumption = 4166.252570
#
# 3) Energy Consumption is directly proportional to no. of appliances used
#
# 4) Energy Consumption is most in industrial buildings, and least in residential buildings
#
# 5) Energy Consumption is directly proportional to no. of occupants
#
# 6) Energy Consumption is somewhat higher at low temperatures than at high temperatures
